# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Caroline Chaim de Lima Carneiro

# %% [markdown]
# ## Pergunta (s) a ser respondida:

# %% [markdown]
# Será que a taxa vegetativa dos países da america do norte cresceu mais que os outros países do mundo com a criação do NAFTA?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
# O acordo do NAFTA, assinado em 1994, criou uma situação de livre comércio entre os três países da américa do Norte: Estados Unidos, México e Canadá.
#
# Para os Estados Unidos e o Canadá, sua atuação no bolco cria uma relação de dependência econômica com os outros países. Portanto, sua atuação no bloco se faz por aumentar suas exportações e aplicar o seu mercado em relção aos outros países do tratado. Além disso, é importante ressaltar o "boom" na economia devido às filiais americanas e canadenses instaladas no México, aproveitando da mão de obra barata. De acordo com Instituto Peterson de Economia Internacional (PIIE), os EUA incorporam uma riqueza anual no valor
# de US$ 127 bilhões todos os anos graças ao crescimento “extra” do comércio propiciado pelo NAFTA.
#
# Apesar do México ser o menos desenvolvido dos três, ele ainda teve um benefício econômico, crescimento de empregos - devido às filiais americanas - e mercado para exportação.
#
# Com tantos crescimentos econômicos vindo dos três países, os avanços políticos e, como consequência um crescimento do IDH, é possível e coerente concluír que haveria um aumento da taxa vegetativa devido ao tratado.

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# Foi utilizado um gráfico de países por taxa vegetativa por ano. Será necessário fazer uma comparação do crescimento vegetativo antes e depois do tratado.
#
# Também foi usando um gráfico de Renda Nacional Bruta (GNI) para visualisar o crescimento econômico de países, considerando o que foi dito na hipótese.
#
# -Provar que ha crescimento do IDH de acordo com a RNB de um país
#
# -Provar que o crescimento vegetativo vem do aumento do IDH
#
# https://www.gapminder.org/data/

# %% [markdown]
# https://www.suapesquisa.com/geografia/nafta.htm

# %% [markdown]
# ## Análise de dados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import os

# Função para a legenda ficar fora do gráfico
def legend_box():
    plt.subplots_adjust(right=0.8)
    plt.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
    
POP= pd.read_excel('population_growth_annual_percent.xlsx')
PIB  = pd.read_excel('PIB.xlsx')
IDH = pd.read_excel ('IDH.xlsx')
GNI = pd.read_excel ('GNI.xlsx')

# %%
POP.head()
# Out:
#        country  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...    \
# 0  Afghanistan  1.82  1.88  1.94  1.99  2.05  2.11  2.13  2.15  2.21  ...
# 1      Albania  3.02  3.12  3.06  2.95  2.88  2.75  2.63  2.63  2.84  ...
# 2      Algeria  2.51  2.49  2.47  2.49  2.56  2.66  2.76  2.84  2.88  ...
# 3      Andorra  7.05  6.94  6.69  6.56  6.24  6.00  5.75  5.50  5.31  ...
# 4       Angola  1.90  1.93  1.95  1.93  1.87  1.79  1.70  1.65  1.68  ...
#
#     2008   2009    2010   2011   2012   2013   2014   2015   2016   2017
# 0  2.510  2.570  2.8100  3.100  3.270  3.320  3.180  2.940  2.690  2.490
# 1 -0.767 -0.674 -0.4960 -0.269 -0.165 -0.183 -0.207 -0.291 -0.160 -0.092
# 2  1.620  1.720  1.8200  1.920  2.010  2.040  2.000  1.920  1.830  1.740
# 3  1.410  0.714 -0.0154 -0.830 -1.590 -2.010 -1.960 -1.540 -0.944 -0.410
# 4  3.560  3.570  3.5700  3.570  3.560  3.530  3.490  3.430  3.370  3.310
#
# [5 rows x 59 columns]

# %%
PIB.head()
# Out:
#        country   1801   1802   1803   1804   1805   1806   1807   1808   1809  \
# 0  Afghanistan    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1      Albania  0.418  0.418  0.418  0.418  0.418  0.418  0.418  0.418  0.418
# 2      Algeria  0.356  0.356  0.356  0.356  0.356  0.356  0.356  0.356  0.356
# 3      Andorra  0.166  0.166  0.166  0.166  0.166  0.166  0.166  0.166  0.166
# 4       Angola  0.425  0.425  0.425  0.425  0.425  0.425  0.425  0.425  0.425
#
#    ...    2004   2005   2006    2007   2008   2009  2010  2011   2012  2013
# 0  ...    6.55  12.40   4.56  13.600   2.50  20.20  8.04  6.98  14.80  4.47
# 1  ...    5.97   5.53   5.77   5.850   7.24   3.28  3.36  2.86   2.64  2.06
# 2  ...    5.41   5.38   1.72   3.420   2.02   1.70  3.57  2.31   2.58  2.99
# 3  ...    8.64   7.80   4.97   0.161  -4.22  -5.06 -3.43 -2.83    NaN   NaN
# 4  ...   11.20  20.50  18.60  23.200  13.80   2.39  3.45  3.87   4.96  3.79
#
# [5 rows x 214 columns]

# %%
IDH.head()
# Out:
#        country   1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# 0  Afghanistan  0.295  0.300  0.309  0.305  0.300  0.324  0.328  0.332  0.335
# 1      Albania  0.635  0.618  0.603  0.608  0.616  0.628  0.637  0.636  0.646
# 2      Algeria  0.577  0.581  0.587  0.591  0.595  0.600  0.609  0.617  0.627
# 3      Andorra    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4       Angola    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    ...     2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0  ...    0.415  0.433  0.434  0.448  0.454  0.463  0.470  0.476  0.479  0.479
# 1  ...    0.703  0.713  0.721  0.725  0.738  0.752  0.759  0.761  0.762  0.764
# 2  ...    0.690  0.697  0.705  0.714  0.724  0.732  0.737  0.741  0.743  0.745
# 3  ...      NaN    NaN    NaN    NaN  0.819  0.819  0.843  0.850  0.857  0.858
# 4  ...    0.454  0.468  0.480  0.488  0.495  0.508  0.523  0.527  0.531  0.533
#
# [5 rows x 27 columns]

# %%
POP = POP.set_index('country')

i = 1994

procura = []

while i < 2018:
    procura.append(i)
    i = i + 1

POP_NAFTA = POP.loc[["Mexico", "United States", "Canada"], procura]

# %%
POP_NAFTA
# Out:
#                 1994   1995  1996  1997   1998   1999   2000  2001   2002  \
# country
# Mexico         1.910  1.820  1.73  1.65  1.570  1.490  1.400  1.32  1.240
# United States  1.230  1.190  1.16  1.20  1.170  1.150  1.110  0.99  0.928
# Canada         0.961  0.828  1.08  1.06  0.866  0.827  0.883  1.01  0.897
#
#                 2003  ...     2008   2009   2010   2011   2012   2013   2014  \
# country               ...
# Mexico         1.220  ...    1.620  1.610  1.560  1.500  1.450  1.400  1.370
# United States  0.859  ...    0.946  0.877  0.833  0.743  0.751  0.711  0.752
# Canada         0.996  ...    1.080  1.140  1.110  0.988  1.180  1.150  1.080
#
#                 2015   2016   2017
# country
# Mexico         1.330  1.300  1.260
# United States  0.756  0.734  0.713
# Canada         0.833  1.200  1.220
#
# [3 rows x 24 columns]

# %%
POP_MUNDI = POP.loc[:, procura]

# %%
POP_MUNDI.head()
# Out:
#               1994   1995   1996    1997   1998   1999   2000   2001  2002  \
# country
# Afghanistan  6.900  5.570  4.140  3.0900  2.590  2.820  3.490  4.250  4.72
# Albania     -0.614 -0.618 -0.622 -0.6250 -0.629 -0.633 -0.637 -0.938 -0.30
# Algeria      2.050  1.890  1.740  1.6000  1.490  1.410  1.350  1.300  1.27
# Andorra      2.760  1.850  0.796 -0.0513 -0.288  0.355  1.570  2.940  3.94
# Angola       3.210  3.040  2.860  2.7300  2.720  2.830  3.030  3.250  3.41
#
#               2003  ...     2008   2009    2010   2011   2012   2013   2014  \
# country             ...
# Afghanistan  4.820  ...    2.510  2.570  2.8100  3.100  3.270  3.320  3.180
# Albania     -0.374  ...   -0.767 -0.674 -0.4960 -0.269 -0.165 -0.183 -0.207
# Algeria      1.270  ...    1.620  1.720  1.8200  1.920  2.010  2.040  2.000
# Andorra      4.380  ...    1.410  0.714 -0.0154 -0.830 -1.590 -2.010 -1.960
# Angola       3.530  ...    3.560  3.570  3.5700  3.570  3.560  3.530  3.490
#
#               2015   2016   2017
# country
# Afghanistan  2.940  2.690  2.490
# Albania     -0.291 -0.160 -0.092
# Algeria      1.920  1.830  1.740
# Andorra     -1.540 -0.944 -0.410
# Angola       3.430  3.370  3.310
#
# [5 rows x 24 columns]

# %%
PIB = PIB.set_index('country')
i = 1994

procura = []

while i < 2014:
    procura.append(i)
    i = i + 1

PIB_NAFTA = PIB.loc[["Mexico", "United States", "Canada"], procura]

# %%
PIB_MUNDI = POP.loc[:, procura]

# %%
IDH = IDH.set_index('country')
i = 1994

procura = []

while i < 2014:
    procura.append(i)
    i = i + 1

IDH_NAFTA = IDH.loc[["Mexico", "United States", "Canada"], procura]

# %%
IDH_MUNDI = IDH.loc[:, procura]

# %%
GNI = GNI.set_index('country')
i = 1994

procura = []

while i < 2014:
    procura.append(i)
    i = i + 1

GNI_NAFTA = GNI.loc[["Mexico", "United States", "Canada"], procura]

# %%
GNI_MUNDI = GNI.loc[:, procura]

# %% [markdown]
# ## Tabela quali e quanti dos países em 1994

# %%
Mundi_Quanti= pd.DataFrame()

# %%
Mundi_Quanti["GNI_1994"]= GNI_MUNDI.loc[:, 1994]
Mundi_Quanti["IDH_1994"]= IDH_MUNDI.loc[:, 1994]
Mundi_Quanti["PIB_1994"]= PIB_MUNDI.loc[:, 1994]
Mundi_Quanti["Tax_Pop_2019"] = POP_MUNDI.loc[:,1994]
Mundi_Quanti["NAFTA"]= "Não"
Mundi_Quanti.NAFTA["United States"] = "Sim"
Mundi_Quanti.NAFTA["Mexico"] = "Sim"
Mundi_Quanti.NAFTA["Canada"] = "Sim"
# Out:
# C:\Users\carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\carol\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Mundi_Quanti.head()
# Out:
#                          GNI_1994  IDH_1994  PIB_1994  Tax_Pop_2019 NAFTA
# country
# Afghanistan                   NaN     0.300     6.900         6.900   Não
# Albania              7.690000e+09     0.616    -0.614        -0.614   Não
# Algeria              1.770000e+11     0.595     2.050         2.050   Não
# Angola               9.570000e+09       NaN     3.210         3.210   Não
# Antigua and Barbuda  8.650000e+08       NaN     2.510         2.510   Não

# %%
Mundi_Quanti.GNI_1994.plot.box()

# %% [markdown]
# ## Aumento do IDH com o aumento do GNI

# %%
y = IDH_MUNDI.mean()
x = y.index

# %%
plt.figure(figsize=(30,10))
plt.plot(x,y)

# %%
y = GNI_MUNDI.mean()
x = y.index

# %%
plt.figure(figsize=(30,10))
plt.plot(x,y)

# %% [markdown]
# ## Aumento do GNI do MÉXICO, EUA E CANADÁ DEPOIS E ANTES DO NAFTA

# %%
 GNI_NAFTA
# Out:
#                        1994          1995          1996          1997  \
# country
# Mexico         8.000000e+11  7.240000e+11  7.750000e+11  8.510000e+11
# United States  7.200000e+12  7.600000e+12  8.080000e+12  8.620000e+12
# Canada         6.310000e+11  6.620000e+11  6.860000e+11  7.290000e+11
#
#                        1998          1999          2000          2001  \
# country
# Mexico         8.990000e+11  9.620000e+11  1.040000e+12  1.050000e+12
# United States  9.170000e+12  9.730000e+12  1.040000e+13  1.080000e+13
# Canada         7.630000e+11  8.150000e+11  8.740000e+11  9.080000e+11
#
#                        2002          2003          2004          2005  \
# country
# Mexico         1.070000e+12  1.110000e+12  1.200000e+12  1.300000e+12
# United States  1.110000e+13  1.160000e+13  1.240000e+13  1.320000e+13
# Canada         9.430000e+11  9.940000e+11  1.060000e+12  1.140000e+12
#
#                        2006          2007          2008          2009  \
# country
# Mexico         1.430000e+12  1.560000e+12  1.650000e+12  1.640000e+12
# United States  1.410000e+13  1.460000e+13  1.480000e+13  1.450000e+13
# Canada         1.220000e+12  1.280000e+12  1.320000e+12  1.280000e+12
#
#                        2010            2011          2012          2013
# country
# Mexico         1.750000e+12   1900000000000  1.980000e+12  2.010000e+12
# United States  1.510000e+13  15800000000000  1.660000e+13  1.710000e+13
# Canada         1.330000e+12   1400000000000  1.440000e+12  1.530000e+12

# %%
Mexico = GNI.loc["Mexico", [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001]] 
USA = GNI.loc["United States", [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001]]
Canada= GNI.loc["Canada",[1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001]]

# %%
Ym = Mexico
Xm = Ym.index
Yu = USA
Xu = Yu.index
Yc = Canada
Xc= Yc.index

# %%
plt.figure(figsize=(10,5))
plt.plot(Xu,Yu)
plt.plot(Xm,Ym)
plt.plot(Xc,Yc)

# %% [markdown]
# ## Gráfico populacional mundial

# %%
POP.head()
# Out:
#              1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# country
# Afghanistan  1.82  1.88  1.94  1.99  2.05  2.11  2.13  2.15  2.21  2.33
# Albania      3.02  3.12  3.06  2.95  2.88  2.75  2.63  2.63  2.84  2.90
# Algeria      2.51  2.49  2.47  2.49  2.56  2.66  2.76  2.84  2.88  2.87
# Andorra      7.05  6.94  6.69  6.56  6.24  6.00  5.75  5.50  5.31  5.20
# Angola       1.90  1.93  1.95  1.93  1.87  1.79  1.70  1.65  1.68  1.81
#
#              ...     2008   2009    2010   2011   2012   2013   2014   2015  \
# country      ...
# Afghanistan  ...    2.510  2.570  2.8100  3.100  3.270  3.320  3.180  2.940
# Albania      ...   -0.767 -0.674 -0.4960 -0.269 -0.165 -0.183 -0.207 -0.291
# Algeria      ...    1.620  1.720  1.8200  1.920  2.010  2.040  2.000  1.920
# Andorra      ...    1.410  0.714 -0.0154 -0.830 -1.590 -2.010 -1.960 -1.540
# Angola       ...    3.560  3.570  3.5700  3.570  3.560  3.530  3.490  3.430
#
#               2016   2017
# country
# Afghanistan  2.690  2.490
# Albania     -0.160 -0.092
# Algeria      1.830  1.740
# Andorra     -0.944 -0.410
# Angola       3.370  3.310
#
# [5 rows x 58 columns]

# %%
POP.sum()[1994]
# Out:
# 299.5303000000001

# %%
Mexico = POP.loc["Mexico", :,]
USA= POP.loc["United States", :,]
Canada= POP.loc["Canada", :,]

y = POP.sum()
x = y.index
Ym = Mexico
Xm = Ym.index
Yu = USA
Xu = Yu.index
Yc = Canada
Xc= Yc.index
Yl= POP.sum()[1994]
Xl = [1994]

# %%
plt.figure(figsize=(30,10))
plt.plot(x,y)
plt.plot (Xl, Yl)

# %%
plt.figure(figsize=(30,10))
plt.plot(Xu,Yu)
plt.plot(Xm,Ym)
plt.plot(Xc,Yc)

# %%
POP_NAFTA.head()
# Out:
#                 1994   1995  1996  1997   1998   1999   2000  2001   2002  \
# country
# Mexico         1.910  1.820  1.73  1.65  1.570  1.490  1.400  1.32  1.240
# United States  1.230  1.190  1.16  1.20  1.170  1.150  1.110  0.99  0.928
# Canada         0.961  0.828  1.08  1.06  0.866  0.827  0.883  1.01  0.897
#
#                 2003  ...     2008   2009   2010   2011   2012   2013   2014  \
# country               ...
# Mexico         1.220  ...    1.620  1.610  1.560  1.500  1.450  1.400  1.370
# United States  0.859  ...    0.946  0.877  0.833  0.743  0.751  0.711  0.752
# Canada         0.996  ...    1.080  1.140  1.110  0.988  1.180  1.150  1.080
#
#                 2015   2016   2017
# country
# Mexico         1.330  1.300  1.260
# United States  0.756  0.734  0.713
# Canada         0.833  1.200  1.220
#
# [3 rows x 24 columns]

# %%
POP.head()
# Out:
#              1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# country
# Afghanistan  1.82  1.88  1.94  1.99  2.05  2.11  2.13  2.15  2.21  2.33
# Albania      3.02  3.12  3.06  2.95  2.88  2.75  2.63  2.63  2.84  2.90
# Algeria      2.51  2.49  2.47  2.49  2.56  2.66  2.76  2.84  2.88  2.87
# Andorra      7.05  6.94  6.69  6.56  6.24  6.00  5.75  5.50  5.31  5.20
# Angola       1.90  1.93  1.95  1.93  1.87  1.79  1.70  1.65  1.68  1.81
#
#              ...     2008   2009    2010   2011   2012   2013   2014   2015  \
# country      ...
# Afghanistan  ...    2.510  2.570  2.8100  3.100  3.270  3.320  3.180  2.940
# Albania      ...   -0.767 -0.674 -0.4960 -0.269 -0.165 -0.183 -0.207 -0.291
# Algeria      ...    1.620  1.720  1.8200  1.920  2.010  2.040  2.000  1.920
# Andorra      ...    1.410  0.714 -0.0154 -0.830 -1.590 -2.010 -1.960 -1.540
# Angola       ...    3.560  3.570  3.5700  3.570  3.560  3.530  3.490  3.430
#
#               2016   2017
# country
# Afghanistan  2.690  2.490
# Albania     -0.160 -0.092
# Algeria      1.830  1.740
# Andorra     -0.944 -0.410
# Angola       3.370  3.310
#
# [5 rows x 58 columns]
